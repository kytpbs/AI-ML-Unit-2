# %%
import numpy as np

# %%
print("Now With Output!")
# Out:
# Now With Output!

# %%
a = np.array([[1, 2, 3], [4, 5, 6]])
np.sum(a, axis=1)
# Thss is ann intentionel typo to tst the typos chcker.
# Out:
# array([ 6, 15])

# %%
# Thss is an second intentionel typo to tst the typos chcker.
print("Please work")
# Out:
# Please work
